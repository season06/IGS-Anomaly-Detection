# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
wait = 400
p_list = [24, 48, 72, 96, 120, 144, 168]
d0_loss = [527.73, 509.74, 505.90, 506.61, 507.54, 504.91, 504.99]
d1_loss = [518.30, 485.69, 495.94, 500.29, 498.04, 496.51, 506.07]
d2_loss = [483.03, 470.44, 460.77, 469.30, 479.99, 482.06, 479.66]
d3_loss = [663.89, 494.31, 476.67, 471.63, 467.73, 462.68, 463.36]

plt.plot(p_list, d0_loss, label='d0_loss')
plt.plot(p_list, d1_loss, label='d1_loss', color='red')
plt.plot(p_list, d2_loss, label='d2_loss', color='green')
plt.plot(p_list, d3_loss, label='d3_loss', color='yellow')

for a, b in zip(p_list, d0_loss):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=15)
for a, b in zip(p_list, d1_loss):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=15)
for a, b in zip(p_list, d2_loss):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=15)
for a, b in zip(p_list, d3_loss):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=15)

plt.rcParams['figure.figsize'] = [25,5]
plt.xticks(p_list, fontsize=15)
plt.yticks(np.arange(455, 670, 20), fontsize=15)
plt.legend(loc='best')
plt.title(f'ARIMA p=(x_axis), d=?, q=0',fontsize=15)
# Out:
# Text(0.5, 1.0, 'ARIMA p=(x_axis), d=?, q=0')

# %%
step_24 = range(8)
loss_24 = [527.73, 544.53, 542.94, 544.81, 531.40, 523.45, 520.95, 524.64]

plt.plot(step_24, loss_24, label='loss')
for a, b in zip(step_24, loss_24):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=12)
plt.xticks(step_24, fontsize=12)
plt.yticks(np.arange(490, 570, 10), fontsize=12)
plt.legend(loc='best')
plt.title(f'ARMA p=24, d=0, q=(x_axis)',fontsize=12)
# Out:
# Text(0.5, 1.0, 'ARMA p=24, d=0, q=(x_axis)')

# %%
step_24_up = [24,48,72,96,120,144,168]
loss_24_up = [499.31, 508.96, 518.27, 547.03, 564.37, 536.07, 547.83]

plt.plot(step_24_up, loss_24_up, label='loss')
for a, b in zip(step_24_up, loss_24_up):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=12)
plt.xticks(step_24_up, fontsize=12)
plt.yticks(np.arange(490, 570, 10), fontsize=12)
plt.legend(loc='best')
plt.title(f'ARMA p=24, d=0, q=(x_axis)',fontsize=12)
# Out:
# Text(0.5, 1.0, 'ARMA p=24, d=0, q=(x_axis)')

# %%
step_48 = range(8)
loss_48 = [509.74, 509.06, 510.32, 509.88, 509.13, 501.07, 498.66, 494.09]

plt.plot(step_48, loss_48, label='loss')
for a, b in zip(step_48, loss_48):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=9)
plt.xticks(step_48, fontsize=12)
plt.yticks(np.arange(490, 570, 10), fontsize=12)
plt.legend(loc='best')
plt.title(f'ARMA p=48, d=0, q=(x_axis)',fontsize=12)
# Out:
# Text(0.5, 1.0, 'ARMA p=48, d=0, q=(x_axis)')

# %%
step_72 = range(8)
loss_72 = [505.90, 505.14, 504.94, 505.32, 504.5, 502.19, 503.46, 502.52]

plt.plot(step_72, loss_72, label='loss')
for a, b in zip(step_72, loss_72):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=9)
plt.xticks(step_72, fontsize=12)
plt.yticks(np.arange(490, 570, 10), fontsize=12)
plt.legend(loc='best')
plt.title(f'ARMA p=72, d=0, q=(x_axis)',fontsize=12)
# Out:
# Text(0.5, 1.0, 'ARMA p=72, d=0, q=(x_axis)')

# %%
step_96 = range(8)
loss_96 = [506.61, 505.95, 505.46, 505.61, 505.97, 504.18, 505.86, 505.89]

plt.plot(step_96, loss_96, label='loss')
for a, b in zip(step_96, loss_96):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=9)
plt.xticks(step_96, fontsize=12)
plt.yticks(np.arange(490, 570, 10), fontsize=12)
plt.legend(loc='best')
plt.title(f'ARMA p=96, d=0, q=(x_axis)',fontsize=12)
# Out:
# Text(0.5, 1.0, 'ARMA p=96, d=0, q=(x_axis)')

# %%
step_120 = range(8)
loss_120 = [507.54, 506.51, 507.02, 506.75, 506.49, 506.69, 506.33, 505.87]

plt.plot(step_120, loss_120, label='loss')
for a, b in zip(step_120, loss_120):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=9)
plt.xticks(step_120, fontsize=12)
plt.yticks(np.arange(490, 570, 10), fontsize=12)
plt.legend(loc='best')
plt.title(f'ARMA p=120, d=0, q=(x_axis)',fontsize=12)
# Out:
# Text(0.5, 1.0, 'ARMA p=120, d=0, q=(x_axis)')

# %%
step_120_2 = range(8)
loss_120_2 = [460.77, 649.78, 606.65, 654.13, 907.27, 938.59, 965.90, 986.18]

plt.plot(step_120_2, loss_120_2, label='loss')
for a, b in zip(step_120_2, loss_120_2):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=9)
plt.xticks(step_120_2, fontsize=12)
plt.yticks(np.arange(450, 990, 50), fontsize=12)
plt.legend(loc='best')
plt.title(f'ARIMA p=72, d=2, q=(x_axis)',fontsize=12)
# Out:
# Text(0.5, 1.0, 'ARIMA p=72, d=2, q=(x_axis)')

# %%
step_120_1 = range(8)
loss_120_1 = [495.94, 496.07, 495.27, 554.85, 511.15, 507.50, 507.96, 500.41]

plt.plot(step_120_1, loss_120_1, label='loss')
for a, b in zip(step_120_1, loss_120_1):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=9)
plt.xticks(step_120_1, fontsize=12)
plt.yticks(np.arange(450, 990, 50), fontsize=12)
plt.legend(loc='best')
plt.title(f'ARIMA p=72, d=1, q=(x_axis)',fontsize=12)
# Out:
# Text(0.5, 1.0, 'ARIMA p=72, d=1, q=(x_axis)')

# %%
x_label = [24, 48, 72, 96, 120] # p
y_label = [24, 48] # q
loss_24_up = [499.31, 508.96]
loss_48_up = [634.34, 510.18]
loss_72_up = [516.05, 505.81]
loss_96_up = [508.81, 536.50]
loss_120_up = [505.71, '-']

c = {
    "24": loss_24_up,
    "48": loss_48_up,
    "72": loss_72_up,
    "96": loss_96_up,
    "120": loss_120_up
}

data=DataFrame(c, index=[24, 48])
print(data)
print("x = p_step, y = q_step")
# Out:
#         24      48      72      96     120
# 24  499.31  634.34  516.05  508.81  505.71
# 48  508.96  510.18  505.81  536.50       -
# x = p_step, y = q_step

# %% [markdown]
# # NEW

# %%
step_0 = [24, 48, 72, 96, 120, 144, 168] # p
loss_0 = [782.84, 755.63, 758.58, 753.47, 754.62, 759.22, 760.41]

plt.plot(step_0, loss_0, label='loss')
for a, b in zip(step_0, loss_0):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=9)
plt.xticks(step_0, fontsize=12)
plt.yticks(np.arange(700, 900, 50), fontsize=12)
plt.legend(loc='best')
plt.title(f'AR p=(x_axis), d=0, q=0',fontsize=12)
# Out:
# Text(0.5, 1.0, 'AR p=(x_axis), d=0, q=0')

# %%
step_7 = [24, 48, 72, 96, 120, 144] # p
loss_7 = [773.02, 729.46, 750.70, 752.64, 751.71, 700]

plt.plot(step_7, loss_7, label='loss')
for a, b in zip(step_7, loss_7):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=9)
plt.xticks(step_7, fontsize=12)
plt.yticks(np.arange(700, 900, 50), fontsize=12)
plt.legend(loc='best')
plt.title(f'ARMA p=(x_axis), d=0, q=7',fontsize=12)
# Out:
# Text(0.5, 1.0, 'ARMA p=(x_axis), d=0, q=7')

# %%
step_24 = [24, 48, 72, 96, 120, 144] # p
loss_24 = [749.74, 890.43, 760.23, 754.85, 751.78, 763.59]

plt.plot(step_24, loss_24, label='loss')
for a, b in zip(step_24, loss_24):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=9)
plt.xticks(step_24, fontsize=12)
plt.yticks(np.arange(700, 900, 50), fontsize=12)
plt.legend(loc='best')
plt.title(f'ARMA p=(x_axis), d=0, q=24',fontsize=12)
# Out:
# Text(0.5, 1.0, 'ARMA p=(x_axis), d=0, q=24')

# %%
step_48 = [24, 48, 72, 96, 120, 144] # p
loss_48 = [748.94, 767.52, 753.71, 776.43, 700, 700]

plt.plot(step_48, loss_48, label='loss')
for a, b in zip(step_48, loss_48):
    plt.text(a, b, '%.2f' % b, ha='center', va= 'bottom',fontsize=9)
plt.xticks(step_48, fontsize=12)
plt.yticks(np.arange(700, 900, 50), fontsize=12)
plt.legend(loc='best')
plt.title(f'ARMA p=(x_axis), d=0, q=48',fontsize=12)
# Out:
# Text(0.5, 1.0, 'ARMA p=(x_axis), d=0, q=48')
