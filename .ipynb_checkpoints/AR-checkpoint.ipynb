# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('ErrorLog_Ver3/errorlog0601_0614_edit.csv')  
df2 = pd.read_csv('ErrorLog_Ver3/errorlog0615_0630_edit.csv')  
df3 = pd.read_csv('ErrorLog_Ver3/errorlog0701_0715_edit.csv')  
df4 = pd.read_csv('ErrorLog_Ver3/errorlog0716_0730_edit.csv')  
df5 = pd.read_csv('ErrorLog_Ver3/errorlog0731_0814_edit.csv')  
df6 = pd.read_csv('ErrorLog_Ver3/errorlog0815_0828_edit.csv')  
df7 = pd.read_csv('ErrorLog_Ver3/errorlog0829_0831_edit.csv')  

df = pd.concat([df1,df2,df3,df4,df5,df6,df7],axis=0, ignore_index=True)
print(df.shape)
df.head(5)
# Out:
# (12169809, 15)
#     EventTime                         SessionID            UserID  \
# 0  1591685860  3d48d3fcd61ee231db62a2c43ef62a50  2020110517651012
# 1  1591685860  3d48d3fcd61ee231db62a2c43ef62a50  2020110517651012
# 2  1591685023  dcd2bfd1ddefb16708789a0e4323cda5  2020110513281012
# 3  1591681945  eb689200531704e41ff9b3665becd317  2020110512131012
# 4  1591671218  6e72fe3f74dd0899547aab7a942924f2  2020110523061012
#
#    ErrorEventID  Channel Country   LV  VipLV  \
# 0      51509999        1      TW  999      4
# 1         12150        1      TW  999      4
# 2       4716002        1      TW  999      2
# 3          8028        3      TW   70      6
# 4      51519999        2      TW  999      6
#
#                                      UDID    State  Machine  TotalBet  \
# 0  "36A58D4F-CB6C-4A7C-B126-A391CE7CEDAF"  MACHINE    114.0       0.0
# 1  "36A58D4F-CB6C-4A7C-B126-A391CE7CEDAF"  MACHINE    114.0       0.0
# 2  "2233ECA1-A30F-4A9A-9FA1-30B0E285A97B"  MACHINE    130.0       0.0
# 3                        c860005a54708320  LOADING    198.0       0.0
# 4                        84d6d768d2ca3801  MACHINE    105.0       0.0
#
#   FeverState PublishVer  CurChannel
# 0       NONE    "9.8.6"         1.0
# 1       NONE    "9.8.6"         1.0
# 2       NONE    "9.8.6"         1.0
# 3       NONE    "9.8.7"         2.0
# 4       NONE    "9.8.7"         2.0

# %%
dates = list(range(6, 13))
hours = list(range(0, 24))
error_hours = []
error_times = []

for date in dates:
    for hour in hours:
        start = datetime.datetime(2020, 6, date, hour, 0, 0, 0)
        end = datetime.datetime(2020, 6, date, hour, 59, 59, 999999)
        
        e = errorlog[errorlog["EventTime"] <= end.timestamp()]    
        e = e[e["EventTime"] >= start.timestamp()]
        t = f"06{date:02d}-{hour:02d}~{(hour+1):02d}"
        error_hours.append(e["EventTime"].count())
        error_times.append(t)

# %%
error_date = []
error_count = []
EventTime = df.EventTime

for _time in EventTime:
    date = datetime.fromtimestamp(_time)
    
    start = datetime(2020, date.month, date.day, date.hour, 0, 0, 0)
    end = datetime(2020, date.month, date.day, date.hour, 59, 59, 999999)
    
    e = errorlog[errorlog["EventTime"] <= end.timestamp()]    
    e = e[e["EventTime"] >= start.timestamp()]
    t = f"06{date:02d}-{hour:02d}~{(hour+1):02d}"
    error_hours.append(e["EventTime"].count())
    error_times.append(t)
# Out:
# 2020-06-09 14:00:00
# 2020-06-09 14:59:59.999999
